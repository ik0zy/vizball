# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fifa_players_15_22_clean.csv')
df.head()
# Out:
# C:\Users\mushf\AppData\Local\Temp\ipykernel_24300\865169959.py:1: DtypeWarning: Columns (25,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('fifa_players_15_22_clean.csv')
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini               CF
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, LM
# 2          A. Robben                         Arjen Robben       RM, LM, RW
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142078 entries, 0 to 142077
# Data columns (total 84 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   sofifa_id                    142078 non-null  int64
#  1   player_url                   142078 non-null  object
#  2   short_name                   142078 non-null  object
#  3   long_name                    142078 non-null  object
#  4   player_positions             142078 non-null  object
#  5   overall                      142078 non-null  int64
#  6   potential                    142078 non-null  int64
#  7   value_eur                    140182 non-null  float64
#  8   wage_eur                     140457 non-null  float64
#  9   age                          142078 non-null  int64
#  10  dob                          142078 non-null  object
#  11  height_cm                    142078 non-null  int64
# ...

# %%
df.describe()
# Out:
#            sofifa_id        overall      potential     value_eur  \
# count  142078.000000  142078.000000  142078.000000  1.401820e+05
# mean   211625.428919      65.706000      70.726249  2.268820e+06
# std     34846.519534       7.064541       6.271633  5.779823e+06
# min         2.000000      40.000000      40.000000  1.000000e+03
# 25%    196142.000000      61.000000      66.000000  3.000000e+05
# 50%    216393.000000      66.000000      70.000000  7.000000e+05
# 75%    234430.000000      70.000000      75.000000  1.800000e+06
# max    264640.000000      94.000000      95.000000  1.940000e+08
#
#             wage_eur            age      height_cm      weight_kg  \
# count  140457.000000  142078.000000  142078.000000  142078.000000
# mean    11113.728045      25.117077     181.206436      75.247871
# std     22251.563020       4.659211       6.734556       6.997593
# min       500.000000      16.000000     154.000000      49.000000
# ...

# %%
df.isna().sum()
# Out:
# sofifa_id                0
# player_url               0
# short_name               0
# long_name                0
# player_positions         0
#                      ...
# club_logo_url         1629
# club_flag_url         1629
# nation_logo_url     133635
# nation_flag_url          0
# year                     0
# Length: 84, dtype: int64
